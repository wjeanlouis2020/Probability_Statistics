# %% [markdown]
# <a href="https://colab.research.google.com/github/wjeanlouis2020/Probability_Statistics/blob/main/Copy_of_Hahn_Stats_2023_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
#Always import libaries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4])

# %% [markdown]
# #This shows the population for the cell

# %%
# population

# %%
np.sum(x)
# Out:
# 10

# %%
x.shape[0]
# Out:
# 4

# %%
#The will have the sum and assume the shape with it

# %%
np.sum(x)/x.shape[0]
# Out:
# 2.5

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %% [markdown]
# #To determine the mean for the product it will be present

# %%
mean(x)
# Out:
# 2.5

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
x - mean(x)
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %%
(x - mean(x))**2
# Out:
# array([2.25, 0.25, 0.25, 2.25])

# %%
 def var(x):
    return mean((x - mean(x))**2)

# %%
#This is the code

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 2.5

# %%
var(x)
# Out:
# 1.25

# %%
std(x)
# Out:
# 1.118033988749895

# %%
#this is not a random cell

# %% [markdown]
# ### Random Number Generator

# %% [markdown]
# $y=mx+b$

# %%
#The beginning steps for the random # generator

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 58      # seed value

# %%
X = np.zeros(50000,)

# %%
#This will be the sum for the function

# %%
x = (m * x + b) % n

# %%
for i in range(X.shape[0]):

    x = (m * x + b) % n
    
    X[i] = x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-055536ed35ba> in <module>
#       3     x = (m * x + b) % n
#       4
# ----> 5     X[i] = x
#
# ValueError: setting an array element with a sequence.

# %%
#It will show the array of numbers

# %%
X
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
X /= np.max(X)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(X[:100],'.')

# %%
plt.hist(X);

# %%
plt.hist(X,100);

# %%
#from the plots and diagrams

# %%
X
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
X
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
X
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,)

# %%
X
# Out:
# array([0.00776595, 0.22011681, 0.07660271, ..., 0.71878709, 0.83019533,
#        0.82489651])

# %%
#This plot has higher values

# %%
plt.hist(X,100);

# %%
np.random.random()
# Out:
# 0.24419930638594578

# %%
r = np.random.random()

# %%
r
# Out:
# 0.12912060519391488

# %%
#R will be a random value

# %%
r = np.random.randint(1,10)

# %%
r
# Out:
# 5

# %%
r = np.random.randint(0,3,size=(1))

# %%
r[0]
# Out:
# 2

# %%
game = ['rock', 'paper', 'scissors']

# %%
game[r[0]]
# Out:
# 'scissors'

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]

# %%
p1,p2
# Out:
# (0, 1)

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]
game[p1],game[p2]
# Out:
# ('scissors', 'scissors')

# %%
import numpy as np

# %%
np.random.randn()
# Out:
# 0.20302116627509245

# %%
numbers  = np.random.randn(2,4)

# %%
numbers.shape
# Out:
# (2, 4)

# %%
numbers = numbers.reshape(-1)

# %%
numbers.shape
# Out:
# (8,)

# %%
# numbers= np.array([1,2,2,3,3,3,4,4,4,4])

# %%
numbers = np.random.randn(100000,)

# %%
numbers.shape
# Out:
# (100000,)

# %%
plt.hist(numbers,100);

# %%
numbers = np.random.rand(1000000,)

# %%
plt.hist(numbers,100);

# %%
np.random.seed(12345)
data = np.random.randn(2, 100)

plt.figure(1, figsize=(9, 9))


plt.subplot(2,2,1)
plt.hist(data[0])

plt.subplot(2,2,2)
plt.scatter(data[0], data[1])

plt.subplot(2,2,3)
plt.plot(data[0], data[1])

plt.subplot(2,2,4)
plt.hist2d(data[0], data[1])

plt.show()

# %% [markdown]
# Normal Dist Data

# %%
x = 50*np.random.randn(10000)

# %%
plt.hist(x);

# %%
x = np.random.rand(1000,)

# %%
plt.hist(x**2);

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x)

# %%
bins
# Out:
# array([ 47.31533866,  58.33504905,  69.35475943,  80.37446981,
#         91.3941802 , 102.41389058, 113.43360096, 124.45331135,
#        135.47302173, 146.49273212, 157.5124425 ])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y)

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %%
def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 100.2686375893311

# %%
std(x)
# Out:
# 14.966815085663306

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %%
x = np.linspace(-10,10,100)
y = 2.71**(-x**2)
plt.plot(x,y)

# %% [markdown]
# $e^{-x^2}$

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))

# %%
x = np.linspace(-6,6,1000)

# %%
mu = 0

# %%
sigma = 1

# %%
pdf = normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')
plt.plot(x,y,'g.')

# %%
def partial_sums(x):

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y

# %%
cdf = partial_sums(pdf)

# %%
plt.plot(x,cdf,'.');

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.');

# %%
def find_nearest(array, value):

  idx = np.argmin(np.abs(array - value))
  
  return idx

# %%
find_nearest(cdf, 0.1)
# Out:
# 393

# %%
x[393]
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,))

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]

# %%
w.shape
# Out:
# (10000,)

# %%
plt.hist(w,50);

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(1,1,3))

# %%
z
# Out:
# array([[[178, 137, 130]]])

# %%
z = np.random.randint(0,255,size=(10,10,3))

# %%
plt.imshow(z)

# %%
z = np.zeros((10,10,3))

# %%
z.shape
# Out:
# (10, 10, 3)

# %%
plt.imshow(z)

# %%
z = 0*np.ones((10,10,3))

# %%
plt.imshow(z)

# %%
z = 255*np.ones((10,10,3))

# %%
plt.imshow(z)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3))

z[:,:,0] = 1
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)

# %%
plt.hist(np.random.randn(1000,)/6 + 1/2)
# Out:
# (array([  4.,  26.,  72., 168., 227., 237., 158.,  78.,  27.,   3.]),
#  array([-0.02606836,  0.07762679,  0.18132194,  0.28501709,  0.38871224,
#          0.49240739,  0.59610254,  0.69979769,  0.80349284,  0.90718799,
#          1.01088314]),
#  <a list of 10 Patch objects>)

# %%
for _ in range(100):
    z = np.ones((10,10,3))

    r = np.random.randn()/6 + 1/2
    g = np.random.randn()/6 + 1/2
    b = np.random.randn()/6 + 1/2

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.5727027256893231 0.42870521493958164 0.7964435081014163
# 0.24928357779514582 0.4606033990950698 0.5839474007285232
# 0.4244662629215261 0.2954730929401972 0.5374915926226568
# 0.5319849540906496 0.7029253406716958 0.6878997945426834
# 0.5434034461556896 0.2122164522206515 0.5682010331110016
# 0.5764664119033418 0.6025002185046895 0.9568347284299128
# 0.6869620877943388 0.6830130108247118 0.590156593961025
# 1.0992006276777124 0.49520170599329894 0.7729716112673789
# 0.6370368075762185 0.3047177382579279 0.36150778164697744
# 0.6034544089339882 0.0734544414057024 0.6596462800700034
# 0.6417043092055986 0.6001883615118258 0.5832060581416405
# 0.41920530685492213 0.25214840384721726 0.42501098469173115
# 0.3197464993382598 0.19794219784972372 0.5280214008255026
# 0.44782447345488696 0.4291198244562399 0.7918455957795072
# 0.581906223208561 0.3256316257916231 0.49167238842121536
# 0.8424288197687919 0.7617202325019354 0.4434238771418111
# 0.38731425049088714 0.6040185769589179 0.7407408246267293
# 0.4323012312008123 0.3315615924605423 0.4943902968629338
# 0.7298578027405238 0.44870296804332205 0.31459471472209466
# 0.6024669951169508 0.5296792630996432 0.5016592261974614
# 0.36346325466679796 0.23977510611820124 0.6959384037189732
# 0.2025705660451424 0.722258044499393 0.3410763070940128
# 0.5086730599414123 0.37855885358336844 0.34631331265213805
# 0.35197619890910337 0.8357452657996165 0.5710857814328794
# 0.49150331676203357 0.696491383338616 0.48830239067463543
# 0.23469679262860837 0.2852208738265487 0.5053947737926884
# 0.7120507431924648 0.04477410213079258 0.5766789425811198
# 0.43676341525474555 0.5114791053960747 0.7551163957934344
# 0.8471296388448133 0.3194411507204572 0.7084659331605602
# 0.39628681305986324 0.4963191163023479 0.4858059023571909
# 0.8161694495138441 0.3393290287656121 0.47504873223929484
# 0.5691176634549071 0.3553732470045212 0.7341669575585882
# 0.5605680964721642 0.4625388032788613 0.30040514614345826
# 0.6292020267756318 0.483426220162032 0.17585261088345483
# 0.39711252231407224 0.0382860092473325 0.44673040972956235
# 0.10756513654410138 0.4017102825817833 0.055853493109749075
# 0.9697278115062833 0.7360569840507964 0.23349951624903376
# 0.7471687377345749 0.31205083956771607 0.430843536671941
# 0.5011327600028207 0.10561504871554961 0.2820639406825025
# 0.017079987562153676 0.5502639207156772 0.3160294637820651
# 0.18732832955410428 0.7069814229059739 0.5634758474031455
# 0.0509559616791585 0.2840487830327765 0.3032303874426572
# 0.9004891033079536 0.3017958434116871 0.8761981107810571
# 0.8262326394049387 0.9453350089894378 0.6997168341588044
# 0.7035708905468616 0.3569418594961844 0.29248972655735783
# 0.21485523977847654 0.7747225158700799 0.3924623194301986
# 0.4454166337145694 0.6840776046449901 0.2547011555007954
# 0.2878018855927449 0.6358371475492959 0.17187280940144511
# 0.9778028874267759 0.45743185174924617 0.17400348921650644
# 0.2649670363994484 0.8096033785864098 0.7922172754352964

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

zavg = (z1+z2)/2

z1a = (z1+zavg)/2
z2a = (z2+zavg)/2

z3 = np.hstack((z1,z1a,zavg,z2a,z2))

plt.imshow(z3);
plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    zavg = (z1+z2)/2

    z1a = (z1+zavg)/2
    z2a = (z2+zavg)/2

    z3 = np.hstack((z1,z1a,zavg,z2a,z2))

    plt.imshow(z3);
    plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
url = 'https://lospec.com/palette-list/agb-32x.png'

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'

# %%
im = imageio.imread(url)

# %%
plt.imshow(im);

# %%
z = np.random.randint(0,255,size=(10,10))

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
