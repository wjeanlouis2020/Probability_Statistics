# %% [markdown]
# <a href="https://colab.research.google.com/github/wjeanlouis2020/Probability_Statistics/blob/main/Jean_Louis_Lab_photos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
from skimage.io import imread

# %%
url = 'https://raw.githubusercontent.com/williamedwardhahn/Data_Sci/main/dataset/train/cat/download.jpg'

# %%
im = imread(url)

# %%
plt.figure(figsize=(20,10))
plt.imshow(im);
plt.axis('off')
# Out:
# (-0.5, 317.5, 158.5, -0.5)
